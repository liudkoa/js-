# %%
import requests
url='http://match.yuanrenxue.com/match/2'
headers={'Host': 'match.yuanrenxue.com',
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36 Edg/90.0.818.51',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Referer': 'http://match.yuanrenxue.com/match/2',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'zh-CN,zh;q=0.9',
    }
response=requests.get(url).text
print(response)
# Out:
# <script>var $a=['\x61\x38\x4f\x73\x77\x37\x4d\x3d','\x4a\x51\x34\x6d','\x62\x7a\x33\x44\x76\x41\x3d\x3d','\x77\x37\x6b\x74\x50\x51\x3d\x3d','\x77\x34\x31\x35\x77\x71\x55\x3d','\x64\x57\x6b\x6c','\x54\x69\x42\x39','\x35\x62\x2b\x4f\x55\x38\x4b\x76','\x4c\x53\x54\x43\x6c\x41\x3d\x3d','\x53\x38\x4f\x4a\x50\x41\x3d\x3d','\x77\x72\x77\x79\x77\x34\x63\x3d','\x77\x6f\x6b\x6e\x77\x35\x38\x3d','\x77\x70\x50\x43\x6f\x38\x4b\x5a','\x45\x38\x4f\x66\x77\x71\x4d\x3d','\x77\x6f\x33\x43\x74\x79\x6f\x3d','\x47\x4d\x4f\x44\x77\x71\x45\x3d','\x77\x72\x42\x44\x41\x41\x3d\x3d','\x77\x35\x6e\x43\x6c\x73\x4f\x64','\x77\x37\x74\x31\x77\x6f\x67\x3d','\x77\x37\x6e\x43\x6b\x4d\x4f\x4b','\x77\x34\x48\x43\x6b\x57\x67\x3d','\x77\x36\x74\x77\x77\x72\x45\x3d','\x77\x72\x56\x42\x50\x41\x3d\x3d','\x77\x34\x6a\x43\x6b\x6e\x51\x3d','\x61\x6c\x66\x43\x76\x67\x3d\x3d','\x77\x70\x4a\x6e\x4e\x41\x3d\x3d','\x77\x72\x50\x43\x71\x38\x4b\x63','\x77\x35\x70\x47\x77\x36\x59\x3d','\x77\x37\x63\x76\x77\x35\x51\x3d','\x77\x70\x62\x
# ...

# %% [markdown]
# #### js代码 location["reload"]();重新请求一次

# %%
import requests
import execjs
def get_m():
    with open('2.js','r',encoding='utf8') as f:
        jecode = f.read()
    sign = execjs.compile(jecode).call('kk')
    return sign
print(get_m())
# Out:
# m=cbb13779c547ed55cb281a8bb6a21a68|1620219381000

# %%
import requests
url='http://match.yuanrenxue.com/match/2'
headers={'Host': 'match.yuanrenxue.com',
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36 Edg/90.0.818.51',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Referer': 'http://match.yuanrenxue.com/match/2',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'zh-CN,zh;q=0.9',
    }
response=requests.get(url)
print(response)
# Out:
# <RequestsCookieJar[]>

# %%
import requests
import execjs
import time 
t1 = time.time()
url='http://match.yuanrenxue.com/api/match/2'
t2 = time.time()
headers={'Accept': 'application/json, text/javascript, */*; q=0.01',
'Accept-Encoding': 'gzip, deflate',
'Accept-Language': 'zh-CN,zh;q=0.9',
'Connection': 'keep-alive',
'Cookie': 'Hm_lvt_c99546cf032aaa5a679230de9a95c7db=1620200620; qpfccr=true; no-alert2=true; Hm_lvt_9bcbda9cbf86757998a2339a0437208e=1620200832; Hm_lpvt_9bcbda9cbf86757998a2339a0437208e={}; Hm_lpvt_c99546cf032aaa5a679230de9a95c7db={}; {}'.format(t1,t2,get_m()),
'Host': 'match.yuanrenxue.com',
'Referer': 'http://match.yuanrenxue.com/match/2',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36 Edg/90.0.818.51',
'X-Requested-With': 'XMLHttpRequest'}
print(headers)
response=requests.get(url,headers=headers).text
print(response)
# Out:
# {'Accept': 'application/json, text/javascript, */*; q=0.01', 'Accept-Encoding': 'gzip, deflate', 'Accept-Language': 'zh-CN,zh;q=0.9', 'Connection': 'keep-alive', 'Cookie': 'Hm_lvt_c99546cf032aaa5a679230de9a95c7db=1620200620; qpfccr=true; no-alert2=true; Hm_lvt_9bcbda9cbf86757998a2339a0437208e=1620200832; Hm_lpvt_9bcbda9cbf86757998a2339a0437208e=1620220124.8609385; Hm_lpvt_c99546cf032aaa5a679230de9a95c7db=1620220124.8609385; m=869d3828c53bc7edc3f5ce7e735e25e0|1620220124000', 'Host': 'match.yuanrenxue.com', 'Referer': 'http://match.yuanrenxue.com/match/2', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36 Edg/90.0.818.51', 'X-Requested-With': 'XMLHttpRequest'}
# {"status": "1", "state": "success", "data": [{"value": 3592}, {"value": 1829}, {"value": 3753}, {"value": 5054}, {"value": 9894}, {"value": 1037}, {"value": 7581}, {"value": 5257}, {"value": 8218}, {"value": 5244}]}
